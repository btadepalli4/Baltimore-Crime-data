# %% [markdown]
# # Importing the Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Loading the Data

# %%
df = pd.read_csv("C:/Users/yasha/Downloads/Part_1_Crime_Data (1).csv")
df.head()
# Out:
# C:\Users\yasha\AppData\Local\Temp\ipykernel_41296\891823045.py:1: DtypeWarning: Columns (9,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("C:/Users/yasha/Downloads/Part_1_Crime_Data (1).csv")
#            X          Y  RowID  CCNumber           CrimeDateTime CrimeCode  \
# 0 -76.584281  39.282869      1  12A01562  2011/12/30 09:37:00+00        6E
# 1 -76.570626  39.367758      2  11L12669  2011/12/30 00:36:00+00       3JF
# 2 -76.562701  39.323386      3  11L13076  2011/12/30 21:00:00+00       3AO
# 3 -76.602909  39.232993      4  12A00628  2011/12/30 09:00:00+00        5A
# 4 -76.576114  39.292284      5  11L13140  2011/12/30 00:13:00+00        4C
#
#     Description Inside_Outside   Weapon Post  ... Ethnicity  \
# 0       LARCENY              I      NaN  214  ...       NaN
# 1       ROBBERY              I  FIREARM  423  ...       NaN
# 2       ROBBERY              O    OTHER  432  ...       NaN
# 3      BURGLARY              I      NaN  913  ...       NaN
# 4  AGG. ASSAULT              O    OTHER  222  ...       NaN
#
#               Location Old_District New_District                 Neighborhood  \
# 0       2300 BOSTON ST    SOUTHEAST          NaN                       CANTON
# 1   6600 MOONFLOWER CT    NORTHEAST          NaN               HAMILTON HILLS
# 2      3400 SHANNON DR    NORTHEAST          NaN                BELAIR-EDISON
# 3     600 E JEFFREY ST     SOUTHERN          NaN                     BROOKLYN
# 4  2900 E BALTIMORE ST    SOUTHEAST          NaN  PATTERSON PARK NEIGHBORHOOD
#
#     Latitude  Longitude             GeoLocation           PremiseType  \
# 0  39.282869 -76.584281  (39.282869,-76.584281)  GARAGE ON PRIV. PROP
# 1  39.367758 -76.570626  (39.367758,-76.570626)     ROW/TOWNHOUSE-OCC
# 2  39.323386 -76.562701  (39.323386,-76.562701)                 ALLEY
# 3  39.232993 -76.602909  (39.232993,-76.602909)     ROW/TOWNHOUSE-OCC
# 4  39.292284 -76.576114  (39.292284,-76.576114)  STREET
#
#    Total_Incidents
# 0                1
# 1                1
# 2                1
# 3                1
# 4                1
#
# [5 rows x 23 columns]

# %% [markdown]
# # Describing the Data

# %%
df.shape
# Out:
# (587673, 23)

# %% [markdown]
# no of rows = 587673
#
# no of columns = 23

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 587673 entries, 0 to 587672
# Data columns (total 23 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   X                586689 non-null  float64
#  1   Y                586689 non-null  float64
#  2   RowID            587673 non-null  int64
#  3   CCNumber         587673 non-null  object
#  4   CrimeDateTime    587673 non-null  object
#  5   CrimeCode        587673 non-null  object
#  6   Description      587673 non-null  object
#  7   Inside_Outside   536412 non-null  object
#  8   Weapon           145090 non-null  object
#  9   Post             579693 non-null  object
#  10  Gender           493050 non-null  object
#  11  Age              473013 non-null  float64
#  12  Race             567987 non-null  object
#  13  Ethnicity        61611 non-null   object
#  14  Location         584616 non-null  object
#  15  Old_District     563488 non-null  object
#  16  New_District     16201 non-null   object
#  17  Neighborhood     579522 non-null  object
#  18  Latitude         586689 non-null  float64
#  19  Longitude        586689 non-null  float64
#  20  GeoLocation      587673 non-null  object
#  21  PremiseType      536076 non-null  object
#  22  Total_Incidents  587673 non-null  int64
# dtypes: float64(5), int64(2), object(16)
# memory usage: 103.1+ MB

# %%
df.columns
# Out:
# Index(['X', 'Y', 'RowID', 'CCNumber', 'CrimeDateTime', 'CrimeCode',
#        'Description', 'Inside_Outside', 'Weapon', 'Post', 'Gender', 'Age',
#        'Race', 'Ethnicity', 'Location', 'Old_District', 'New_District',
#        'Neighborhood', 'Latitude', 'Longitude', 'GeoLocation', 'PremiseType',
#        'Total_Incidents'],
#       dtype='object')

# %% [markdown]
# # Droping unnecessary columns

# %%
drop_columns = ['X','Y','RowID','CCNumber','CrimeCode','Post','Location','Neighborhood','New_District','GeoLocation','Total_Incidents','PremiseType']
df1 = df.drop(drop_columns,axis=1)
df1.head()
# Out:
#             CrimeDateTime   Description Inside_Outside   Weapon Gender   Age  \
# 0  2011/12/30 09:37:00+00       LARCENY              I      NaN      M  42.0
# 1  2011/12/30 00:36:00+00       ROBBERY              I  FIREARM      M  22.0
# 2  2011/12/30 21:00:00+00       ROBBERY              O    OTHER      M   NaN
# 3  2011/12/30 09:00:00+00      BURGLARY              I      NaN      F  28.0
# 4  2011/12/30 00:13:00+00  AGG. ASSAULT              O    OTHER      M  21.0
#
#                         Race Ethnicity Old_District   Latitude  Longitude
# 0                    UNKNOWN       NaN    SOUTHEAST  39.282869 -76.584281
# 1  BLACK_OR_AFRICAN_AMERICAN       NaN    NORTHEAST  39.367758 -76.570626
# 2                      WHITE       NaN    NORTHEAST  39.323386 -76.562701
# 3                      WHITE       NaN     SOUTHERN  39.232993 -76.602909
# 4  BLACK_OR_AFRICAN_AMERICAN       NaN    SOUTHEAST  39.292284 -76.576114

# %% [markdown]
# # Checking for null Values

# %%
df1.isnull().sum()
# Out:
# CrimeDateTime          0
# Description            0
# Inside_Outside     51261
# Weapon            442583
# Gender             94623
# Age               114660
# Race               19686
# Ethnicity         526062
# Old_District       24185
# Latitude             984
# Longitude            984
# dtype: int64

# %%
# Percentage of nulls
df1.isnull().sum().map(lambda r:(r/len(df1))*100)
# Out:
# CrimeDateTime      0.000000
# Description        0.000000
# Inside_Outside     8.722708
# Weapon            75.311100
# Gender            16.101301
# Age               19.510850
# Race               3.349822
# Ethnicity         89.516108
# Old_District       4.115384
# Latitude           0.167440
# Longitude          0.167440
# dtype: float64

# %% [markdown]
# ####  As the columns 'Weapons' and 'Ethnicity' have null percentages exceeding 75%, the decision is to eliminate these columns instead of attempting to fill the missing values.

# %%
df1 = df1.drop(['Weapon','Ethnicity'],axis=1)
df1.head()
# Out:
#             CrimeDateTime   Description Inside_Outside Gender   Age  \
# 0  2011/12/30 09:37:00+00       LARCENY              I      M  42.0
# 1  2011/12/30 00:36:00+00       ROBBERY              I      M  22.0
# 2  2011/12/30 21:00:00+00       ROBBERY              O      M   NaN
# 3  2011/12/30 09:00:00+00      BURGLARY              I      F  28.0
# 4  2011/12/30 00:13:00+00  AGG. ASSAULT              O      M  21.0
#
#                         Race Old_District   Latitude  Longitude
# 0                    UNKNOWN    SOUTHEAST  39.282869 -76.584281
# 1  BLACK_OR_AFRICAN_AMERICAN    NORTHEAST  39.367758 -76.570626
# 2                      WHITE    NORTHEAST  39.323386 -76.562701
# 3                      WHITE     SOUTHERN  39.232993 -76.602909
# 4  BLACK_OR_AFRICAN_AMERICAN    SOUTHEAST  39.292284 -76.576114

# %%
df1.isnull().sum().map(lambda r:(r/len(df1))*100)
# Out:
# CrimeDateTime      0.000000
# Description        0.000000
# Inside_Outside     8.722708
# Gender            16.101301
# Age               19.510850
# Race               3.349822
# Old_District       4.115384
# Latitude           0.167440
# Longitude          0.167440
# dtype: float64

# %%
df1.Latitude.describe()
# Out:
# count    586689.000000
# mean         38.862409
# std           4.155544
# min           0.000000
# 25%          39.287644
# 50%          39.302351
# 75%          39.326408
# max          39.372088
# Name: Latitude, dtype: float64

# %%
df1.Longitude.describe()
# Out:
# count    586689.000000
# mean        -75.751416
# std           8.099980
# min         -76.711280
# 25%         -76.648495
# 50%         -76.613711
# 75%         -76.586055
# max           0.000000
# Name: Longitude, dtype: float64

# %%
df1[(df1.Longitude == 0) & (df1.Latitude == 0) ]
# Out:
#                  CrimeDateTime        Description Inside_Outside Gender   Age  \
# 42      2011/03/21 12:00:00+00           BURGLARY              I    NaN   NaN
# 453     2012/06/19 09:45:00+00         AUTO THEFT              O      M  22.0
# 616     2011/06/18 12:00:00+00         AUTO THEFT              O      M  47.0
# 755     2011/03/01 11:45:00+00  LARCENY FROM AUTO              O      F  68.0
# 1157    2011/02/17 03:30:00+00     COMMON ASSAULT              O      M  23.0
# ...                        ...                ...            ...    ...   ...
# 586099  2012/02/01 12:50:00+00  LARCENY FROM AUTO              O      F  26.0
# 586190  2011/11/15 13:00:00+00  LARCENY FROM AUTO              O      F  19.0
# 586272  2012/01/31 20:45:00+00     COMMON ASSAULT              I      F  31.0
# 586554  2011/11/06 12:50:00+00  LARCENY FROM AUTO              O      M  28.0
# 586574  2011/11/06 16:45:00+00       AGG. ASSAULT              O      M  36.0
#
#                              Race Old_District  Latitude  Longitude
# 42                        UNKNOWN          NaN       0.0        0.0
# 453                         WHITE          NaN       0.0        0.0
# 616                         WHITE          NaN       0.0        0.0
# 755                         WHITE          NaN       0.0        0.0
# 1157                        WHITE          NaN       0.0        0.0
# ...                           ...          ...       ...        ...
# 586099  BLACK_OR_AFRICAN_AMERICAN          NaN       0.0        0.0
# 586190  BLACK_OR_AFRICAN_AMERICAN          NaN       0.0        0.0
# 586272  BLACK_OR_AFRICAN_AMERICAN          NaN       0.0        0.0
# 586554                      WHITE          NaN       0.0        0.0
# 586574                      WHITE          NaN       0.0        0.0
#
# [6632 rows x 9 columns]

# %% [markdown]
# #### Certain rows are exhibiting the latitude and longitude values as 0, which is illogical for data according to Baltimore City. Hence, these entries are removed.

# %%
df1 = df1[(df1.Latitude!=0)|(df1.Longitude!=0)]

# %%
df1.Latitude.describe()
# Out:
# count    580057.000000
# mean         39.306737
# std           0.029543
# min          39.200107
# 25%          39.288009
# 50%          39.302963
# 75%          39.326911
# max          39.372088
# Name: Latitude, dtype: float64

# %%
df1.Longitude.describe()
# Out:
# count    580057.000000
# mean        -76.617509
# std           0.042504
# min         -76.711280
# 25%         -76.648913
# 50%         -76.614102
# 75%         -76.587412
# max         -76.529748
# Name: Longitude, dtype: float64

# %% [markdown]
# #### If we look at the descrptive stats of the columns Latitude and Longitude, means and medians of these columns are almost equal so nulls can be filled by mean or median.

# %%
df1.Latitude = df1.Latitude.fillna(value=df1.Latitude.median())
df1.Longitude = df1.Longitude.fillna(value=df1.Longitude.median())

# %%
df1.Age.describe()
# Out:
# count    467551.000000
# mean         37.901555
# std          35.878158
# min       -7979.000000
# 25%          26.000000
# 50%          35.000000
# 75%          49.000000
# max        8251.000000
# Name: Age, dtype: float64

# %%
df1[(df1.Age<=7) | (df1.Age>100)]
# Out:
#                  CrimeDateTime     Description Inside_Outside Gender  Age  \
# 102     2011/10/21 18:10:00+00        BURGLARY              I      F  0.0
# 284     2012/08/30 17:30:00+00    AGG. ASSAULT              I      M  6.0
# 546     2011/03/06 12:43:00+00    AGG. ASSAULT              O      M  3.0
# 558     2011/03/06 12:43:00+00    AGG. ASSAULT              O      M  0.0
# 615     2011/06/18 14:00:00+00  COMMON ASSAULT            NaN      F  7.0
# ...                        ...             ...            ...    ...  ...
# 586259  2011/11/14 14:15:00+00        BURGLARY              I      F  0.0
# 586611  2023/08/27 03:00:00+00           ARSON         Inside      M  5.0
# 586626  2023/08/23 23:33:00+00    AGG. ASSAULT        Outside      F  3.0
# 586845  2023/09/01 15:46:00+00  COMMON ASSAULT        Outside      M  2.0
# 587148  2023/08/26 15:43:09+00  COMMON ASSAULT        Outside      M  0.0
#
#                              Race Old_District   Latitude  Longitude
# 102                         WHITE    SOUTHEAST  39.292442 -76.586979
# 284     BLACK_OR_AFRICAN_AMERICAN    NORTHEAST  39.345239 -76.549757
# 546     BLACK_OR_AFRICAN_AMERICAN     NORTHERN  39.315003 -76.622020
# 558     BLACK_OR_AFRICAN_AMERICAN     NORTHERN  39.315003 -76.622020
# 615     BLACK_OR_AFRICAN_AMERICAN    SOUTHWEST  39.280953 -76.649606
# ...                           ...          ...        ...        ...
# 586259  BLACK_OR_AFRICAN_AMERICAN    NORTHEAST  39.318909 -76.549072
# 586611                        NaN          NaN  39.328255 -76.609355
# 586626  BLACK_OR_AFRICAN_AMERICAN          NaN  39.350610 -76.582686
# 586845  BLACK_OR_AFRICAN_AMERICAN          NaN  39.342670 -76.672144
# 587148  BLACK_OR_AFRICAN_AMERICAN          NaN  39.298732 -76.649181
#
# [2804 rows x 9 columns]

# %% [markdown]
#  #### There are some entries which has age less than 0 and certain entries has age value in thousands. As age cant be in negative and  that high, considering only age range of 8 - 100 and droping of all other entries.

# %%
df1 = df1[(df1.Age>7) & (df1.Age<100)]

# %%
df1.Age.describe()
# Out:
# count    464733.000000
# mean         38.175053
# std          15.497595
# min           8.000000
# 25%          26.000000
# 50%          35.000000
# 75%          49.000000
# max          99.000000
# Name: Age, dtype: float64

# %% [markdown]
# #### Filling the nulls with medians for column Age

# %%
df1.Age = df1.Age.fillna(value = df1.Age.median())

# %% [markdown]
# #### Filling categorical variables with mode

# %%
df1.Old_District = df1.Old_District.fillna(value = df1.Old_District.mode()[0])
df1.Gender = df1.Gender.fillna(value = df1.Gender.mode()[0])
df1.Inside_Outside = df1.Inside_Outside.fillna(value = df1.Inside_Outside.mode()[0])
df1.Race = df1.Race.fillna(value = df1.Race.mode()[0])

# %%
#nulls after filling 
df1.isnull().sum()
# Out:
# CrimeDateTime     0
# Description       0
# Inside_Outside    0
# Gender            0
# Age               0
# Race              0
# Old_District      0
# Latitude          0
# Longitude         0
# dtype: int64

# %%
df1_num = df1.select_dtypes(include = np.number)
df1_num.head()
# Out:
#     Age   Latitude  Longitude
# 0  42.0  39.282869 -76.584281
# 1  22.0  39.367758 -76.570626
# 3  28.0  39.232993 -76.602909
# 4  21.0  39.292284 -76.576114
# 5  42.0  39.307359 -76.599017

# %% [markdown]
# # Check for outliers

# %%
fig,ax=plt.subplots(nrows=2,ncols=2,figsize=(15,10))
for v,s in zip(df1_num.columns,ax.flatten()):
    sns.boxplot(df1_num[v],ax=s)
plt.show()

# %% [markdown]
# #### Even though there are few outliers in columns 'Age' and 'Latitude', as there are only few, not treating them.

# %% [markdown]
# #### Converting description column into target by encoding the column. Considering Rape,Shooting,homicide,arson, Aggravated Assault,Burglay as violent crimes and encoding them as 1 and remaining else 0.

# %%
def violent_encod(value):
    if value in ['RAPE','HOMICIDE','ARSON','SHOOTING','BURGLARY','AGG. ASSAULT']:
        return 1
    else:
        return 0

# %%
df1['violent_crime'] = df.Description.apply(violent_encod)
df1.violent_crime.value_counts()
# Out:
# 0    332234
# 1    132499
# Name: violent_crime, dtype: int64

# %%
df1.head()
# Out:
#             CrimeDateTime   Description Inside_Outside Gender   Age  \
# 0  2011/12/30 09:37:00+00       LARCENY              I      M  42.0
# 1  2011/12/30 00:36:00+00       ROBBERY              I      M  22.0
# 3  2011/12/30 09:00:00+00      BURGLARY              I      F  28.0
# 4  2011/12/30 00:13:00+00  AGG. ASSAULT              O      M  21.0
# 5  2011/12/30 22:11:00+00  AGG. ASSAULT              O      M  42.0
#
#                         Race Old_District   Latitude  Longitude  violent_crime
# 0                    UNKNOWN    SOUTHEAST  39.282869 -76.584281              0
# 1  BLACK_OR_AFRICAN_AMERICAN    NORTHEAST  39.367758 -76.570626              0
# 3                      WHITE     SOUTHERN  39.232993 -76.602909              1
# 4  BLACK_OR_AFRICAN_AMERICAN    SOUTHEAST  39.292284 -76.576114              1
# 5  BLACK_OR_AFRICAN_AMERICAN      EASTERN  39.307359 -76.599017              1

# %% [markdown]
# # Checking categorical data for anomolies

# %%
df1.Inside_Outside.value_counts()
# Out:
# O          214758
# I          157399
# Outside     50817
# Inside      41759
# Name: Inside_Outside, dtype: int64

# %% [markdown]
# #### There are 4 different classes in the column 'Inside_Outside', where I and Inside class indicates that the crime happened inside and O and Outside classes indicates  that the crime happened outside. Converting I and Inside into Inside and O and Outside into Outside

# %%
def inside_outside_conv(value):
    if value in ['Inside','I']:
        return 'Inside'
    else:
        return 'Outside'

# %%
df1.Inside_Outside = df1.Inside_Outside.apply(inside_outside_conv)
df1.Inside_Outside.value_counts()
# Out:
# Outside    265575
# Inside     199158
# Name: Inside_Outside, dtype: int64

# %%
df1.Gender.value_counts()
# Out:
# F             245426
# M             208309
# Male            8581
# U               1169
# Female          1051
# B                120
# W                 19
# N                 12
# ,                 11
# Transgende         9
# FB                 5
# 160                2
# O                  2
# 8                  1
# MB                 1
# 120                1
# 77                 1
# 17                 1
# 165                1
# A                  1
# FF                 1
# S                  1
# FM                 1
# 042819             1
# M\                 1
# T                  1
# FU                 1
# FW                 1
# D                  1
# 50                 1
# Name: Gender, dtype: int64

# %% [markdown]
# #### There are lot of classes in the variable 'Gender'. Converting all of them into 3 categories 'M','F','U'.

# %%
def gend_conv(value):
    if value in ['Male','M']:
        return 'M'
    elif value in ['Female','F']:
        return 'F'
    else:
        return 'U'

# %%
df1.Gender = df1.Gender.apply(gend_conv)
df1.Gender.value_counts()
# Out:
# F    246477
# M    216890
# U      1366
# Name: Gender, dtype: int64

# %%
df1.Race.value_counts()
# Out:
# BLACK_OR_AFRICAN_AMERICAN                    300182
# WHITE                                        115759
# UNKNOWN                                       46294
# ASIAN                                          1407
# AMERICAN_INDIAN_OR_ALASKA_NATIVE                735
# NATIVE_HAWAIIAN_OR_OTHER_PACIFIC_ISLANDER       356
# Name: Race, dtype: int64

# %%
df1.Old_District.value_counts()
# Out:
# NORTHEAST    85101
# SOUTHEAST    61047
# SOUTHERN     51490
# CENTRAL      50756
# NORTHERN     47679
# SOUTHWEST    46144
# NORTHWEST    45168
# EASTERN      40106
# WESTERN      37240
# ND               1
# NWD              1
# Name: Old_District, dtype: int64

# %% [markdown]
# #### If we look at the categories of Old_District, for categories NWD and ND, there are only one entry each. The impact of the these categories on the target cant be explained as no of rows in these categories is very low. So removing those rows.

# %%
df1 = df1[(df1.Old_District != 'NWD') & (df1.Old_District != 'ND')]

# %%
df1.Old_District.value_counts()
# Out:
# NORTHEAST    85101
# SOUTHEAST    61047
# SOUTHERN     51490
# CENTRAL      50756
# NORTHERN     47679
# SOUTHWEST    46144
# NORTHWEST    45168
# EASTERN      40106
# WESTERN      37240
# Name: Old_District, dtype: int64

# %% [markdown]
# # Visualizations

# %% [markdown]
# # Understanding Violent Crime by Gender: Crime Type Chart

# %%
pd.crosstab(index=df1.Gender,columns=df1.violent_crime).plot(kind='bar')
plt.show()

# %%
df1.columns
# Out:
# Index(['CrimeDateTime', 'Description', 'Inside_Outside', 'Gender', 'Age',
#        'Race', 'Old_District', 'Latitude', 'Longitude', 'violent_crime'],
#       dtype='object')

# %% [markdown]
# # Crime Location Analysis: Inside vs. Outside Incidents

# %%
pd.crosstab(index = df1.Inside_Outside,columns = df1.violent_crime).plot(kind='bar')
plt.show()

# %% [markdown]
# sns.barplot(df1.violent_crime,df1.Age)
# plt.show()

# %% [markdown]
# #### By this graph we can say that age does not have a significant influence on the occurrence of violent crimes.

# %% [markdown]
# # Exploring Violent Crimes Across Different Racial Groups

# %%
pd.crosstab(index = df1.Race,columns = df1.violent_crime).plot(kind='bar')
plt.show()

# %% [markdown]
# #### Based on this graph, it appears that a larger number of crimes have been reported among individuals who identify as Black or African American.

# %%
pd.crosstab(index = df1.Old_District,columns = df1.violent_crime).plot(kind='bar')
plt.show()

# %% [markdown]
# #### By this graph we can say most of the crimes are happening in northeastern area

# %%
df1.head()
# Out:
#             CrimeDateTime   Description Inside_Outside Gender   Age  \
# 0  2011/12/30 09:37:00+00       LARCENY         Inside      M  42.0
# 1  2011/12/30 00:36:00+00       ROBBERY         Inside      M  22.0
# 3  2011/12/30 09:00:00+00      BURGLARY         Inside      F  28.0
# 4  2011/12/30 00:13:00+00  AGG. ASSAULT        Outside      M  21.0
# 5  2011/12/30 22:11:00+00  AGG. ASSAULT        Outside      M  42.0
#
#                         Race Old_District   Latitude  Longitude  violent_crime
# 0                    UNKNOWN    SOUTHEAST  39.282869 -76.584281              0
# 1  BLACK_OR_AFRICAN_AMERICAN    NORTHEAST  39.367758 -76.570626              0
# 3                      WHITE     SOUTHERN  39.232993 -76.602909              1
# 4  BLACK_OR_AFRICAN_AMERICAN    SOUTHEAST  39.292284 -76.576114              1
# 5  BLACK_OR_AFRICAN_AMERICAN      EASTERN  39.307359 -76.599017              1

# %% [markdown]
# # Extracting Year, Month, Date, and hour from the column 'CrimeDateTime'

# %%
df1['Year'] = df1.CrimeDateTime.map(lambda x:int(x[0:4]))
df1['Month'] = df1.CrimeDateTime.map(lambda x:int(x[5:7]))
df1['Day'] = df1.CrimeDateTime.map(lambda x:int(x[8:10]))
df1['time_hour'] = df1.CrimeDateTime.map(lambda x:int(x[11:13]))

# %%
df1.head()
# Out:
#             CrimeDateTime   Description Inside_Outside Gender   Age  \
# 0  2011/12/30 09:37:00+00       LARCENY         Inside      M  42.0
# 1  2011/12/30 00:36:00+00       ROBBERY         Inside      M  22.0
# 3  2011/12/30 09:00:00+00      BURGLARY         Inside      F  28.0
# 4  2011/12/30 00:13:00+00  AGG. ASSAULT        Outside      M  21.0
# 5  2011/12/30 22:11:00+00  AGG. ASSAULT        Outside      M  42.0
#
#                         Race Old_District   Latitude  Longitude  \
# 0                    UNKNOWN    SOUTHEAST  39.282869 -76.584281
# 1  BLACK_OR_AFRICAN_AMERICAN    NORTHEAST  39.367758 -76.570626
# 3                      WHITE     SOUTHERN  39.232993 -76.602909
# 4  BLACK_OR_AFRICAN_AMERICAN    SOUTHEAST  39.292284 -76.576114
# 5  BLACK_OR_AFRICAN_AMERICAN      EASTERN  39.307359 -76.599017
#
#    violent_crime  Year  Month  Day  time_hour
# 0              0  2011     12   30          9
# 1              0  2011     12   30          0
# 3              1  2011     12   30          9
# 4              1  2011     12   30          0
# 5              1  2011     12   30         22

# %% [markdown]
# # Peak Hours of Criminal Activity: Analyzing Crime Occurrences

# %%
hour = list(df1.time_hour.value_counts().index)
no_of_crimes = list(df1.time_hour.value_counts().values) 
plt.figure(figsize=(15,5))
sns.lineplot(x=hour,y=no_of_crimes)
plt.xticks(hour)
plt.show()

# %% [markdown]
# ## Crimes Across the Calendar: Analyzing Monthly Patterns

# %%
month = list(df1.Month.value_counts().index)
no_of_crimes = list(df1.Month.value_counts().values) 
plt.figure(figsize=(15,5))
sns.lineplot(x=month,y=no_of_crimes)
plt.xticks(month)
plt.show()

# %% [markdown]
# #### Considering only data from year 2011

# %%
df1 = df1[df1.Year>=2011]

# %% [markdown]
# ## Crimes Across the Calendar: Analyzing yearly Patterns

# %%
year = list(df1.Year.value_counts().index)
no_of_crimes = list(df1.Year.value_counts().values) 
plt.figure(figsize=(15,5))
sns.lineplot(x=year,y=no_of_crimes)
plt.xticks(year)
plt.show()

# %%
df1.columns
# Out:
# Index(['CrimeDateTime', 'Description', 'Inside_Outside', 'Gender', 'Age',
#        'Race', 'Old_District', 'Latitude', 'Longitude', 'violent_crime',
#        'Year', 'Month', 'Day', 'time_hour'],
#       dtype='object')

# %%
plt.figure(figsize=(10, 8))
plt.scatter(df1['Longitude'], df1['Latitude'], c=df1['violent_crime'], cmap='viridis', s=20, alpha=0.6)
plt.colorbar(label='violent_crime')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title('Scatter Plot of Latitude and Longitude with Target')
plt.show()

# %% [markdown]
# #### This graph illustrates various types of crimes, with yellow dots indicating violent offenses and violet dots regular crimes.

# %%
plt.figure(figsize=(10, 8))
plt.hexbin(df1['Longitude'], df1['Latitude'], C=df1['violent_crime'].astype('object'), gridsize=50, cmap='viridis')
plt.colorbar(label='violent_crime')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title('Hexbin Plot of Latitude and Longitude with Target')
plt.show()

# %%
data_for_pairplot = df1[['Latitude', 'Longitude', 'violent_crime']]

sns.pairplot(data_for_pairplot, hue='violent_crime', plot_kws={'alpha': 0.6})
plt.suptitle('Pairplot of Latitude, Longitude, and violent_crime', y=1.02)
plt.show()

# %% [markdown]
# # Classification models

# %% [markdown]
# #### Categorical encoding

# %%
df1.columns
# Out:
# Index(['CrimeDateTime', 'Description', 'Inside_Outside', 'Gender', 'Age',
#        'Race', 'Old_District', 'Latitude', 'Longitude', 'violent_crime',
#        'Year', 'Month', 'Day', 'time_hour'],
#       dtype='object')

# %%
df1.Inside_Outside.value_counts()
# Out:
# Outside    265534
# Inside     199042
# Name: Inside_Outside, dtype: int64

# %%
df1.Gender.value_counts()
# Out:
# F    246346
# M    216864
# U      1366
# Name: Gender, dtype: int64

# %% [markdown]
# As there are only 2 categories in the column 'Inside_Outside' and 3 categories in the column 'gender',using get dummies

# %%
encoded_data = pd.get_dummies(df1[['Inside_Outside','Gender']],drop_first=True)

# %%
df1 = pd.concat([df1,encoded_data],axis=1)
df1.head()
# Out:
#             CrimeDateTime   Description Inside_Outside Gender   Age  \
# 0  2011/12/30 09:37:00+00       LARCENY         Inside      M  42.0
# 1  2011/12/30 00:36:00+00       ROBBERY         Inside      M  22.0
# 3  2011/12/30 09:00:00+00      BURGLARY         Inside      F  28.0
# 4  2011/12/30 00:13:00+00  AGG. ASSAULT        Outside      M  21.0
# 5  2011/12/30 22:11:00+00  AGG. ASSAULT        Outside      M  42.0
#
#                         Race Old_District   Latitude  Longitude  \
# 0                    UNKNOWN    SOUTHEAST  39.282869 -76.584281
# 1  BLACK_OR_AFRICAN_AMERICAN    NORTHEAST  39.367758 -76.570626
# 3                      WHITE     SOUTHERN  39.232993 -76.602909
# 4  BLACK_OR_AFRICAN_AMERICAN    SOUTHEAST  39.292284 -76.576114
# 5  BLACK_OR_AFRICAN_AMERICAN      EASTERN  39.307359 -76.599017
#
#    violent_crime  Year  Month  Day  time_hour  Inside_Outside_Outside  \
# 0              0  2011     12   30          9                       0
# 1              0  2011     12   30          0                       0
# 3              1  2011     12   30          9                       0
# 4              1  2011     12   30          0                       1
# 5              1  2011     12   30         22                       1
#
#    Gender_M  Gender_U
# 0         1         0
# 1         1         0
# 3         0         0
# 4         1         0
# 5         1         0

# %%
df1.Race.value_counts()
# Out:
# BLACK_OR_AFRICAN_AMERICAN                    300064
# WHITE                                        115731
# UNKNOWN                                       46285
# ASIAN                                          1405
# AMERICAN_INDIAN_OR_ALASKA_NATIVE                735
# NATIVE_HAWAIIAN_OR_OTHER_PACIFIC_ISLANDER       356
# Name: Race, dtype: int64

# %%
df1.Old_District.value_counts()
# Out:
# NORTHEAST    85077
# SOUTHEAST    61031
# SOUTHERN     51471
# CENTRAL      50746
# NORTHERN     47656
# SOUTHWEST    46132
# NORTHWEST    45147
# EASTERN      40089
# WESTERN      37227
# Name: Old_District, dtype: int64

# %% [markdown]
# Using label encoder for the columns 'Old_District' and 'Race' as there are more catgories

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()

# %%
df1['Old_District_encoded'] = encoder.fit_transform(df1['Old_District'])
df1['Race_encoded'] = encoder.fit_transform(df1['Race'])

# %%
df1.head()
# Out:
#             CrimeDateTime   Description Inside_Outside Gender   Age  \
# 0  2011/12/30 09:37:00+00       LARCENY         Inside      M  42.0
# 1  2011/12/30 00:36:00+00       ROBBERY         Inside      M  22.0
# 3  2011/12/30 09:00:00+00      BURGLARY         Inside      F  28.0
# 4  2011/12/30 00:13:00+00  AGG. ASSAULT        Outside      M  21.0
# 5  2011/12/30 22:11:00+00  AGG. ASSAULT        Outside      M  42.0
#
#                         Race Old_District   Latitude  Longitude  \
# 0                    UNKNOWN    SOUTHEAST  39.282869 -76.584281
# 1  BLACK_OR_AFRICAN_AMERICAN    NORTHEAST  39.367758 -76.570626
# 3                      WHITE     SOUTHERN  39.232993 -76.602909
# 4  BLACK_OR_AFRICAN_AMERICAN    SOUTHEAST  39.292284 -76.576114
# 5  BLACK_OR_AFRICAN_AMERICAN      EASTERN  39.307359 -76.599017
#
#    violent_crime  Year  Month  Day  time_hour  Inside_Outside_Outside  \
# 0              0  2011     12   30          9                       0
# 1              0  2011     12   30          0                       0
# 3              1  2011     12   30          9                       0
# 4              1  2011     12   30          0                       1
# 5              1  2011     12   30         22                       1
#
#    Gender_M  Gender_U  Old_District_encoded  Race_encoded
# 0         1         0                     5             4
# 1         1         0                     2             2
# 3         0         0                     6             5
# 4         1         0                     5             2
# 5         1         0                     1             2

# %%
df1.columns
# Out:
# Index(['CrimeDateTime', 'Description', 'Inside_Outside', 'Gender', 'Age',
#        'Race', 'Old_District', 'Latitude', 'Longitude', 'violent_crime',
#        'Year', 'Month', 'Day', 'time_hour', 'Inside_Outside_Outside',
#        'Gender_M', 'Gender_U', 'Old_District_encoded', 'Race_encoded'],
#       dtype='object')

# %% [markdown]
# Sorting the data by the date. For doing it sorting the data by hour, day, month, year so that we will get the data in order of date.

# %%
df1 = df1.sort_values(by=['time_hour','Day','Month','Year'])

# %%
df2 = df1[['Age','Latitude', 'Longitude','Year', 'Month', 'Day', 'time_hour', 'Inside_Outside_Outside',
       'Gender_M', 'Gender_U', 'Old_District_encoded', 'Race_encoded','violent_crime']]

# %%
df2.head()
# Out:
#          Age   Latitude  Longitude  Year  Month  Day  time_hour  \
# 518181  20.0  39.292497 -76.611250  2011      1    1          0
# 518291  26.0  39.276987 -76.613380  2011      1    1          0
# 518292  79.0  39.309296 -76.628978  2011      1    1          0
# 518293  28.0  39.323589 -76.549758  2011      1    1          0
# 518417  42.0  39.286675 -76.607713  2011      1    1          0
#
#         Inside_Outside_Outside  Gender_M  Gender_U  Old_District_encoded  \
# 518181                       1         0         0                     0
# 518291                       0         0         0                     6
# 518292                       1         1         0                     0
# 518293                       0         1         0                     2
# 518417                       1         1         0                     0
#
#         Race_encoded  violent_crime
# 518181             2              0
# 518291             5              0
# 518292             2              0
# 518293             4              1
# 518417             5              0

# %%
df2 = df2.reset_index(drop = True)
df2.head()
# Out:
#     Age   Latitude  Longitude  Year  Month  Day  time_hour  \
# 0  20.0  39.292497 -76.611250  2011      1    1          0
# 1  26.0  39.276987 -76.613380  2011      1    1          0
# 2  79.0  39.309296 -76.628978  2011      1    1          0
# 3  28.0  39.323589 -76.549758  2011      1    1          0
# 4  42.0  39.286675 -76.607713  2011      1    1          0
#
#    Inside_Outside_Outside  Gender_M  Gender_U  Old_District_encoded  \
# 0                       1         0         0                     0
# 1                       0         0         0                     6
# 2                       1         1         0                     0
# 3                       0         1         0                     2
# 4                       1         1         0                     0
#
#    Race_encoded  violent_crime
# 0             2              0
# 1             5              0
# 2             2              0
# 3             4              1
# 4             5              0

# %% [markdown]
# # Spliting the data

# %%
X = df2.drop('violent_crime',axis=1)
y = df2['violent_crime']

# %% [markdown]
# As we are considering time columns as predictors, not spliting the data randomly

# %%
print("The length of the data frame :",len(df2))
print("Index for 70% of the data = :",len(df2)*0.7)
# Out:
# The length of the data frame : 464576
# Index for 70% of the data = : 325203.19999999995

# %% [markdown]
# Considering data from index 0 to index 325204 as training data and remaining data as test data

# %%
x_train = X.iloc[0:325204]
x_test = X.iloc[325204:]

# %%
y_train = y.iloc[0:325204]
y_test = y.iloc[325204:]

# %% [markdown]
# # Logistic Regression

# %%
#scaling the data

# %%
from sklearn.preprocessing import StandardScaler
std_scaler = StandardScaler()

# %%
x_train_sc = std_scaler.fit_transform(X=x_train)
x_train_sc = pd.DataFrame(x_train_sc,columns = X.columns)
x_train_sc.head()
# Out:
#         Age  Latitude  Longitude      Year     Month      Day  time_hour  \
# 0 -1.169370 -0.490778   0.155106 -1.543334 -1.682207 -1.64252  -1.737084
# 1 -0.788055 -1.017700   0.104788 -1.543334 -1.682207 -1.64252  -1.737084
# 2  2.580234  0.079942  -0.263636 -1.543334 -1.682207 -1.64252  -1.737084
# 3 -0.660949  0.565522   1.607540 -1.543334 -1.682207 -1.64252  -1.737084
# 4  0.228787 -0.688567   0.238643 -1.543334 -1.682207 -1.64252  -1.737084
#
#    Inside_Outside_Outside  Gender_M  Gender_U  Old_District_encoded  \
# 0                0.909615 -0.922085 -0.054837             -1.533685
# 1               -1.099366 -0.922085 -0.054837              0.892582
# 2                0.909615  1.084498 -0.054837             -1.533685
# 3               -1.099366  1.084498 -0.054837             -0.724929
# 4                0.909615  1.084498 -0.054837             -1.533685
#
#    Race_encoded
# 0     -0.708493
# 1      1.550184
# 2     -0.708493
# 3      0.797292
# 4      1.550184

# %%
x_test_sc = std_scaler.fit_transform(X=x_test)
x_test_sc = pd.DataFrame(x_test_sc,columns = X.columns)
x_test_sc.head()
# Out:
#         Age  Latitude  Longitude      Year     Month       Day  time_hour  \
# 0  2.704998 -0.137423   0.086243 -1.565509 -1.743491  0.400234  -1.778696
# 1  1.028634  1.169223  -1.560590 -1.565509 -1.743491  0.400234  -1.778696
# 2  0.425143 -0.472492  -0.042189 -1.565509 -1.743491  0.400234  -1.778696
# 3 -0.647730  0.139420   0.127315 -1.297302 -1.743491  0.400234  -1.778696
# 4 -0.446566 -0.724204   0.458063 -1.297302 -1.743491  0.400234  -1.778696
#
#    Inside_Outside_Outside  Gender_M  Gender_U  Old_District_encoded  \
# 0                0.769075  1.033019 -0.053041             -0.752826
# 1                0.769075 -0.968036 -0.053041              0.065688
# 2                0.769075  1.033019 -0.053041             -1.571339
# 3                0.769075 -0.968036 -0.053041             -1.162083
# 4                0.769075  1.033019 -0.053041              0.474945
#
#    Race_encoded
# 0      1.548824
# 1     -0.708383
# 2      1.548824
# 3     -0.708383
# 4     -0.708383

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()

# %%
model = lr.fit(x_train_sc,y_train)
y_pred_lr = model.predict(x_test_sc)

# %%
from sklearn.metrics import accuracy_score,recall_score,precision_score,f1_score,roc_auc_score

# %%
lr_acc = accuracy_score(y_test,y_pred_lr)
lr_pre = precision_score(y_test,y_pred_lr)
lr_rec = recall_score(y_test,y_pred_lr)
lr_f1  = f1_score(y_test,y_pred_lr)
lr_roc = roc_auc_score(y_test,y_pred_lr)
print("Accuracy score of Logistic Regression is: ",lr_acc)
print("Precision score of Logistic Regression is: ",lr_pre)
print("Recall score of Logistic Regression is: ",lr_rec)
print("F1 score of Logistic Regression is: ",lr_f1)
print("roc auc score of Logistic Regression is: ",lr_roc)
# Out:
# Accuracy score of Logistic Regression is:  0.7440518899061505
# Precision score of Logistic Regression is:  0.4389408099688474
# Recall score of Logistic Regression is:  0.08077275854161889
# F1 score of Logistic Regression is:  0.13643846228333495
# roc auc score of Logistic Regression is:  0.5231492903385327

# %%
A = []
P = []
R = []
F = []
Ro = []
M = []
A.append(lr_acc)
P.append(lr_pre)
R.append(lr_rec)
F.append(lr_f1)
Ro.append(lr_roc)
M.append('Logistic Regression')

# %% [markdown]
# # KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier()

# %%
model = knn.fit(x_train_sc,y_train)
y_pred_knn = model.predict(x_test_sc)

# %%
knn_acc = accuracy_score(y_test,y_pred_knn)
knn_pre = precision_score(y_test,y_pred_knn)
knn_rec = recall_score(y_test,y_pred_knn)
knn_f1  = f1_score(y_test,y_pred_knn)
knn_roc = roc_auc_score(y_test,y_pred_knn)
print("Accuracy score of KNN is: ",knn_acc)
print("Precision score of KNN is: ",knn_pre)
print("Recall score of KNN is: ",knn_rec)
print("F1 score of KNN is: ",knn_f1)
print("roc auc score of KNN is: ",knn_roc)
# Out:
# Accuracy score of KNN is:  0.7131705077059954
# Precision score of KNN is:  0.4026778882938026
# Recall score of KNN is:  0.3017083237789498
# F1 score of KNN is:  0.3449564134495641
# roc auc score of KNN is:  0.5761345876005886

# %%
A.append(knn_acc)
P.append(knn_pre)
R.append(knn_rec)
F.append(knn_f1)
Ro.append(knn_roc)
M.append('KNN')

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
dtc = DecisionTreeClassifier()

# %%
model = dtc.fit(x_train,y_train)
y_pred_dtc = model.predict(x_test)

# %%
dtc_acc = accuracy_score(y_test,y_pred_dtc)
dtc_pre = precision_score(y_test,y_pred_dtc)
dtc_rec = recall_score(y_test,y_pred_dtc)
dtc_f1  = f1_score(y_test,y_pred_dtc)
dtc_roc = roc_auc_score(y_test,y_pred_dtc)
print("Accuracy score of Decision Tree Classifier is: ",dtc_acc)
print("Precision score of Decision Tree Classifier is: ",dtc_pre)
print("Recall score of Decision Tree Classifier is: ",dtc_rec)
print("F1 score of Decision Tree Classifier is: ",dtc_f1)
print("roc auc score of Decision Tree Classifier is: ",dtc_roc)
# Out:
# Accuracy score of Decision Tree Classifier is:  0.6649183480182533
# Precision score of Decision Tree Classifier is:  0.3474521552726052
# Recall score of Decision Tree Classifier is:  0.3856053657418023
# F1 score of Decision Tree Classifier is:  0.3655358865325309
# roc auc score of Decision Tree Classifier is:  0.5718942184170135

# %%
A.append(dtc_acc)
P.append(dtc_pre)
R.append(dtc_rec)
F.append(dtc_f1)
Ro.append(dtc_roc)
M.append('Decision Tree')

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier()

# %%
model = rfc.fit(x_train,y_train)
y_pred_rfc = model.predict(x_test)

# %%
rfc_acc = accuracy_score(y_test,y_pred_rfc)
rfc_pre = precision_score(y_test,y_pred_rfc)
rfc_rec = recall_score(y_test,y_pred_rfc)
rfc_f1  = f1_score(y_test,y_pred_rfc)
rfc_roc = roc_auc_score(y_test,y_pred_rfc)
print("Accuracy score of Random Forest Classifier is: ",rfc_acc)
print("Precision score of Random Forest Classifier is: ",rfc_pre)
print("Recall score of Random Forest Classifier is: ",rfc_rec)
print("F1 score of Random Forest Classifier is: ",rfc_f1)
print("roc auc score of Random Forest Classifier is: ",rfc_roc)
# Out:
# Accuracy score of Random Forest Classifier is:  0.7547714031512786
# Precision score of Random Forest Classifier is:  0.5243551042810098
# Recall score of Random Forest Classifier is:  0.2190724604448521
# F1 score of Random Forest Classifier is:  0.30903283195859615
# roc auc score of Random Forest Classifier is:  0.5763589016362309

# %%
A.append(rfc_acc)
P.append(rfc_pre)
R.append(rfc_rec)
F.append(rfc_f1)
Ro.append(rfc_roc)
M.append('Random Forest Classifier')

# %% [markdown]
# # Ada boost

# %%
from sklearn.ensemble import AdaBoostClassifier
adc = AdaBoostClassifier()

# %%
model = adc.fit(x_train,y_train)
y_pred_adc = model.predict(x_test)

# %%
adc_acc = accuracy_score(y_test,y_pred_adc)
adc_pre = precision_score(y_test,y_pred_adc)
adc_rec = recall_score(y_test,y_pred_adc)
adc_f1  = f1_score(y_test,y_pred_adc)
adc_roc = roc_auc_score(y_test,y_pred_adc)
print("Accuracy score of AdaBoost Classifier is: ",adc_acc)
print("Precision score of AdaBoost Classifier is: ",adc_pre)
print("Recall score of AdaBoost Classifier is: ",adc_rec)
print("F1 score of AdaBoost Classifier is: ",adc_f1)
print("roc auc score of AdaBoost Classifier is: ",adc_roc)
# Out:
# Accuracy score of AdaBoost Classifier is:  0.7486152168297793
# Precision score of AdaBoost Classifier is:  0.46885521885521886
# Recall score of AdaBoost Classifier is:  0.0319307498280211
# F1 score of AdaBoost Classifier is:  0.059789609274366676
# roc auc score of AdaBoost Classifier is:  0.5099261727395149

# %%
A.append(adc_acc)
P.append(adc_pre)
R.append(adc_rec)
F.append(adc_f1)
Ro.append(adc_roc)
M.append('Ada boost')

# %% [markdown]
# # Gradient boosting

# %%
from sklearn.ensemble import GradientBoostingClassifier
gbc = GradientBoostingClassifier()

# %%
model = gbc.fit(x_train,y_train)
y_pred_gbc = model.predict(x_test)

# %%
gbc_acc = accuracy_score(y_test,y_pred_gbc)
gbc_pre = precision_score(y_test,y_pred_gbc)
gbc_rec = recall_score(y_test,y_pred_gbc)
gbc_f1  = f1_score(y_test,y_pred_gbc)
gbc_roc = roc_auc_score(y_test,y_pred_gbc)
print("Accuracy score of AdaBoost Classifier is: ",gbc_acc)
print("Precision score of AdaBoost Classifier is: ",gbc_pre)
print("Recall score of AdaBoost Classifier is: ",gbc_rec)
print("F1 score of AdaBoost Classifier is: ",gbc_f1)
print("roc auc score of AdaBoost Classifier is: ",gbc_roc)
# Out:
# Accuracy score of AdaBoost Classifier is:  0.7532431191344029
# Precision score of AdaBoost Classifier is:  0.5265406386841824
# Recall score of AdaBoost Classifier is:  0.14130933272185278
# F1 score of AdaBoost Classifier is:  0.2228198232808298
# roc auc score of AdaBoost Classifier is:  0.54944089200313

# %%
A.append(gbc_acc)
P.append(gbc_pre)
R.append(gbc_rec)
F.append(gbc_f1)
Ro.append(gbc_roc)
M.append('Gradient Boosting')

# %% [markdown]
# # Xgboost

# %%
from xgboost import XGBClassifier
xgbc=XGBClassifier()

# %%
model = xgbc.fit(x_train,y_train)
y_pred_xgb = model.predict(x_test)

# %%
xgbc_acc = accuracy_score(y_test,y_pred_xgb)
xgbc_pre = precision_score(y_test,y_pred_xgb)
xgbc_rec = recall_score(y_test,y_pred_xgb)
xgbc_f1  = f1_score(y_test,y_pred_xgb)
xgbc_roc = roc_auc_score(y_test,y_pred_xgb)
print("Accuracy score of AdaBoost Classifier is: ",xgbc_acc)
print("Precision score of AdaBoost Classifier is: ",xgbc_pre)
print("Recall score of AdaBoost Classifier is: ",xgbc_rec)
print("F1 score of AdaBoost Classifier is: ",xgbc_f1)
print("roc auc score of AdaBoost Classifier is: ",xgbc_roc)
# Out:
# Accuracy score of AdaBoost Classifier is:  0.7589185776196079
# Precision score of AdaBoost Classifier is:  0.5457906712172924
# Recall score of AdaBoost Classifier is:  0.22001834441641827
# F1 score of AdaBoost Classifier is:  0.3136133355123386
# roc auc score of AdaBoost Classifier is:  0.5794398984438051

# %%
A.append(xgbc_acc)
P.append(xgbc_pre)
R.append(xgbc_rec)
F.append(xgbc_f1)
Ro.append(xgbc_roc)
M.append('Xgboost')

# %%
scores_df = pd.DataFrame({'Model_name':M,'Accuracy_Score':A,'Precision_Score':P,'Recall_Score':R,'F1 Score':F,'ROC AUC Score':Ro})
scores_df.sort_values(by=['Accuracy_Score','Recall_Score','Precision_Score'],ascending=False)
# Out:
#                  Model_name  Accuracy_Score  Precision_Score  Recall_Score  \
# 6                   Xgboost        0.758919         0.545791      0.220018
# 3  Random Forest Classifier        0.754771         0.524355      0.219072
# 5         Gradient Boosting        0.753243         0.526541      0.141309
# 4                 Ada boost        0.748615         0.468855      0.031931
# 0       Logistic Regression        0.744052         0.438941      0.080773
# 1                       KNN        0.713171         0.402678      0.301708
# 2             Decision Tree        0.664918         0.347452      0.385605
#
#    F1 Score  ROC AUC Score
# 6  0.313613       0.579440
# 3  0.309033       0.576359
# 5  0.222820       0.549441
# 4  0.059790       0.509926
# 0  0.136438       0.523149
# 1  0.344956       0.576135
# 2  0.365536       0.571894
